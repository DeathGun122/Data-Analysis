# %%
file = open('10kDiabetes.csv')

# %%
content = file.read()
file.close()

# %%
import csv

data_dict = {}
for index, row in enumerate(csv.reader(content.strip().split('\n'))):
    if index == 0:
        for column in row:
            data_dict[column] = []
    else:
        for col_index, value in enumerate(row):
            data_dict[list(data_dict.keys())[col_index]].append(value)

# %%
import pandas as pd

# %%
contents = pd.read_csv('10kDiabetes.csv')

# %%
contents['time_in_hospital'].sum()
# Out:
# np.int64(44347)

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- -----------
# aiohappyeyeballs              2.4.4
# aiohttp                       3.11.10
# aiosignal                     1.2.0
# alabaster                     0.7.16
# anaconda-anon-usage           0.7.1
# anaconda-auth                 0.8.6
# anaconda-cli-base             0.5.2
# anaconda-client               1.13.0
# anaconda-navigator            2.6.6
# annotated-types               0.6.0
# anyio                         4.7.0
# archspec                      0.2.3
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.3.0
# astroid                       3.3.8
# asttokens                     3.0.0
# async-lru                     2.0.4
# asyncssh                      2.17.0
# atomicwrites                  1.4.0
# attrs                         24.3.0
# autopep8                      2.0.4
# babel                         2.16.0
# ...
